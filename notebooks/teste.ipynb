# %%
"""
Script to test the finite difference derivatives.
"""

import os
os.chdir('/Users/felipeminuzzi/Library/Mobile Documents/com~apple~CloudDocs/Documents/NumericalMath/')

import numpy as np
import src.derivatives as der

# %load_ext autoreload
# %autoreload 2

diff = der.FirstOrder()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
x        = np.empty([1, 50])
x[0, :]  = np.linspace(0, 2*np.pi, 50)
dx       = x[0, 1] - x[0, 0]

y = np.sin(x)

y_prime_2 = diff.differentiateFirstFO(x, y, dx)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-9f21b74239da> in <module>
#       5 y = np.sin(x)
#       6
# ----> 7 y_prime_2 = diff.differentiateFirstFO(x, y, dx)
#
# ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/NumericalMath/src/derivatives.py in differentiateFirstFO(self, x, y, h)
#      17         diff = np.empty(data_dim)
#      18
# ---> 19         diff[0]  = (y[1] - y[0])/h
#      20         diff[-1] = (y[-1] - y[-2])/h
#      21
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
from matplotlib import pyplot as plt
y_prime_exact = np.cos(x)

fig, ax = plt.subplots()
ax.plot(x[0,:], y_prime_2, linestyle = ':', label='firs order first derivative', linewidth=3)
ax.plot(x[0,:], y_prime_exact[0, :], label='exact', linewidth=1)

plt.xlim(0.0, 2.0*np.pi)
plt.ylim(-1.0, 1.0)
plt.tick_params(axis='both', which='major', labelsize=12)

plt.xlabel('x', fontsize=14)
plt.ylabel('y', fontsize=14)

legend = ax.legend(loc='upper center', shadow = False)
